# %% [markdown]
# # ABS Quarterly National Accounts 5206 - No 2
#
# Productivity and Capital measures from the National Accounts.
#
# **Note:** The following sections require data from the ABS Modeller's Database (1364.0.15.003), which is released about one to two days after the Quarterly National Accounts:
# - Solow Residual (Multifactor Productivity)
# - GDP Growth Decomposition
# - Capital Stock: Perpetual Inventory vs ABS Modellers Database
# - Capital Stock Growth and Capital Deepening
# - Capital Productivity
#
# **Note:** The Market Sector Labour Productivity by Industry section also needs the quarterly Labour Account (6150.0.55.003), which is released about one to two weeks after the Quarterly National Accounts. If this notebook is run in that window the latest quarter's hours are not yet available, so that chart will be one quarter short until the Labour Account is published and the notebook is re-run.

# %% [markdown]
# ## Python set-up

# %%
# system imports
import textwrap
from typing import Any

# analytic imports
import numpy as np
import pandas as pd
import readabs as ra
from readabs import metacol as mc
from statsmodels.tsa.filters.hp_filter import hpfilter

from mgplot import (
    calc_growth,
    line_plot_finalise,
    postcovid_plot_finalise,
    series_growth_plot_finalise,
    growth_plot_finalise,
    multi_start,
)

# %%
# local imports
from abs_helper import (
    get_abs_data,
    ANNUAL_CPI_TARGET_RANGE,
    QUARTERLY_CPI_TARGET,
)
from henderson import hma

# pandas display settings
pd.options.display.max_rows = 999999
pd.options.display.max_columns = 999

# display charts within this notebook
SHOW = False
FILE_TYPE = "png"

# starts
bar_starts = (0, -19)
line_starts = (0, -25)

# %% [markdown]
# ## Get data from ABS

# %%
abs_dict, meta, source, _ = get_abs_data("5206.0", chart_dir_suffix=" - Productivity")

# Frequently used names ...
KEY_AGGS = "5206001_Key_Aggregates"
CVM = "Chain volume measures"
CP = "Current prices"
VALUE_TEXT = "$ Millions"

# %%
meta = meta[~meta[mc.table].str.contains("Mock-up")]

# %%
# Let's see the spreadsheets we have captured
tw = textwrap.TextWrapper(width=80)
tw.wrap(", ".join(abs_dict.keys()))
# Out:
# ['5206001_Key_Aggregates, 5206002_Expenditure_Volume_Measures,',
#  '5206003_Expenditure_Current_Price, 5206004_Expenditure_Price_Indexes,',
#  '5206005_Expenditure_Implicit_Price_Deflators, 5206006_Industry_GVA,',
#  '5206007_Income_From_GDP, 5206008_Household_Final_Consumption_Expenditure,',
#  '5206009_Changes_In_Inventories, 5206010_Agricultural_Income,',
#  '5206011_National_Income_Account, 5206012_National_Capital_Account,',
#  '5206013_NFC_Income, 5206014_PriNFC_Income, 5206015_PubNFC_Income,',
#  '5206016_FC_Income, 5206017_Gen_Govt_Income_Account,',
#  '5206018_Nat_Gen_Govt_Income_Account, 5206019_StateLocal_Gen_Govt_Income_Account,',
#  '5206020_Household_Income, 5206021_External_Account, 5206022_Taxes,',
#  '5206023_Social_Assistance_Benefits, 5206024_Selected_Analytical_Series,',
#  '5206025_SFD_Summary, 5206026_SFD_NSW, 5206027_SFD_VIC, 5206028_SFD_QLD,',
#  '5206029_SFD_SA, 5206030_SFD_WA, 5206031_SFD_TAS, 5206032_SFD_NT,',
# ...

# %% [markdown]
# ## Plot

# %% [markdown]
# ### Labour Productivity

# %%
def labour_productivity() -> None:
    """Plot labour productivity measures with comparisons and long-run trends."""

    table = KEY_AGGS
    data = abs_dict[table]
    series_type = "Seasonally Adjusted"

    # Productivity series from Key Aggregates
    productivity_dids = {
        "GDP per hour worked": "GDP per hour worked: Index ;",
        "GVA per hour worked (Market sector)": "Gross value added per hour worked market sector: Index ;",
    }

    common: dict[str, Any] = {
        "rfooter": f"{source} {table}",
        "lfooter": f"Australia. {series_type}. ",
        "pre_tag": "productivity-",
        "show": SHOW,
        "file_type": FILE_TYPE,
    }

    # --- Individual productivity charts ---
    productivity_data = {}
    for label, did in productivity_dids.items():
        selector = {
            table: mc.table,
            series_type: mc.stype,
            did: mc.did,
        }
        try:
            _table, series_id, units = ra.find_abs_id(meta, selector, verbose=False)
            series = data[series_id].dropna()
            productivity_data[label] = series

            # Level charts
            multi_start(
                series,
                function=line_plot_finalise,
                starts=line_starts,
                title=label,
                ylabel=units,
                annotate=True,
                **common,
            )

            # COVID recovery
            postcovid_plot_finalise(
                series,
                title=label,
                ylabel=units,
                tag="covid",
                annotate=[False, True],
                **common,
            )

            # Growth charts
            series_growth_plot_finalise(
                series,
                title=f"{label} growth",
                plot_from=-19,
                tag="growth",
                **common,
            )
        except Exception as e:
            print(f"Could not find {label}: {e}")

    if not productivity_data:
        print("No productivity series found")
        return

    # --- Productivity comparison chart ---
    comparison = pd.DataFrame(productivity_data).dropna()
    # Rebase to common start
    comparison = comparison / comparison.iloc[0] * 100
    line_plot_finalise(
        comparison,
        title="Labour Productivity: GDP vs Market Sector GVA",
        ylabel="Index (start = 100)",
        annotate=True,
        legend={"loc": "best", "fontsize": 9},
        **common,
    )

    # Annual growth comparison
    growth_comparison = pd.DataFrame(productivity_data).pct_change(periods=4) * 100
    line_plot_finalise(
        growth_comparison.dropna(),
        title="Labour Productivity Growth (YoY)",
        ylabel="Per cent",
        tag="growth-comparison",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        **common,
    )

    # --- Long-run productivity trends with Henderson MA ---
    for label, series in productivity_data.items():
        growth = series.pct_change(periods=4) * 100
        growth = growth.dropna()
        
        hma_term = 13
        smoothed = hma(growth, hma_term)
        
        df = pd.DataFrame({
            "Annual growth": growth,
            f"{hma_term}-term HMA": smoothed,
        })
        
        line_plot_finalise(
            df,
            title=f"{label} - Long-run Growth Trends",
            ylabel="Per cent growth (YoY)",
            width=[1, 3],
            annotate=[False, True],
            y0=True,
            legend={"loc": "best", "fontsize": 9},
            tag="long-run",
            **common,
        )


labour_productivity()

# %% [markdown]
# ### Real Unit Labour Costs
#
# Real ULC in the 5206 Key Aggregates is published **Trend-only**, and the ABS suspended quarterly trend estimates from 2019Q2 (during COVID the symmetric trend filter became unreliable), so the series ends at **2019Q1** — it was not a flaw in ULC itself. The charts below therefore stop in 2019. The productivity overlay keeps the current (Seasonally Adjusted) GDP-per-hour line at full span, and the final chart validates a **self-calculated** real ULC (`COE ÷ nominal GDP`, 13-term Henderson-smoothed for comparability) against the ABS Trend series.

# %%
def real_unit_labour_costs() -> None:
    """Plot real unit labour costs, compare against labour productivity, and set a
    self-calculated real ULC against both the discontinued ABS quarterly series
    and the ABS's own (still current) annual series.

    The quarterly ABS real ULC (5206 Key Aggregates) is Trend-only and ends at
    2019Q1 (the ABS suspended quarterly trend estimates from 2019Q2 during COVID).
    The ABS still applies its formula annually in the ASNA (5204.0), current to
    the latest financial year.
    """

    table = KEY_AGGS
    data = abs_dict[table]
    income_table = "5206007_Income_From_GDP"
    ulc_stype = "Trend"
    series_type = "Seasonally Adjusted"
    hma_term = 13

    common: dict[str, Any] = {
        "rfooter": f"{source} {table}",
        "lfooter": f"Australia. {ulc_stype}. ",
        "pre_tag": "productivity-",
        "show": SHOW,
        "file_type": FILE_TYPE,
    }

    # --- ABS Real ULC level charts (total and non-farm, index-level only) ---
    real_ulc_rows = meta[
        (meta[mc.table] == table) &
        (meta[mc.stype] == ulc_stype) &
        (meta[mc.did].str.contains("Real unit of labour costs", case=False, na=False)) &
        (~meta[mc.did].str.contains("Percentage", case=False, na=False))
    ]

    ulc_data = {}
    for _, row in real_ulc_rows.iterrows():
        series_id = row[mc.id]
        units = row[mc.unit]
        did = row[mc.did]
        label = did.replace(" ;", "").replace(": Index", "").strip()

        series = data[series_id].dropna()
        ulc_data[label] = series

        multi_start(
            series,
            function=line_plot_finalise,
            starts=line_starts,
            title=label,
            ylabel=units,
            annotate=True,
            **common,
        )

    if not ulc_data:
        print("No real ULC series found")
        return

    # ABS Real ULC, total (not non-farm)
    abs_rulc = next(
        (val for key, val in ulc_data.items() if "non-farm" not in key.lower()),
        None,
    )

    # GDP per hour worked (Seasonally Adjusted, current) for the productivity overlay
    _, lp_id, _ = ra.find_abs_id(
        meta,
        {table: mc.table, series_type: mc.stype, "GDP per hour worked: Index ;": mc.did},
        verbose=False,
    )
    gdp_prod = abs_dict[table][lp_id].dropna()

    # --- Productivity vs (ABS) Real ULC comparison ---
    # GDP per hour worked is Seasonally Adjusted and current; real ULC is Trend
    # and ends 2019Q1. Deliberately do NOT dropna so the productivity line keeps
    # its full span instead of being truncated back to the ULC end date.
    if abs_rulc is not None:
        comp_df = pd.DataFrame({
            "Labour Productivity (GDP/hour)": gdp_prod / gdp_prod.iloc[0] * 100,
            "Real Unit Labour Costs": abs_rulc / abs_rulc.iloc[0] * 100,
        })

        line_plot_finalise(
            comp_df,
            title="Labour Productivity vs Real Unit Labour Costs",
            ylabel="Index (start = 100)",
            annotate=True,
            legend={"loc": "best", "fontsize": 9},
            tag="vs-ulc",
            rfooter=f"{source} {table}",
            lfooter="Australia. GDP per hour: SA; Real ULC: Trend (ends 2019Q1). ",
            pre_tag="productivity-",
            show=SHOW,
            file_type=FILE_TYPE,
        )

    # --- Self-calculated Real ULC, against the ABS quarterly and annual series ---
    # ABS real ULC = (COE / employee hours) / (GVA chain-volume / total hours),
    # with labour cost deflated by the GDP implicit price deflator. We cannot
    # reproduce that quarterly because economy-wide *employee* hours are not
    # published quarterly. Our proxy collapses the hours basis to a single (total)
    # measure, leaving real ULC = COE / nominal GDP (the labour income share):
    #     nominal ULC = COE / real GDP ;  real ULC = nominal ULC / deflator = COE / nominal GDP
    # It tracks the ABS series to the mid-1990s but drifts above it post-2000 (the
    # missing employee/total-hours wedge). Our series is SA, so we 13-term Henderson
    # smooth it; the ABS quarterly series is Trend. We also overlay the ABS's own
    # formula output, which is still published annually in the ASNA (5204.0).
    _, gdp_cp_id, _ = ra.find_abs_id(
        meta,
        {table: mc.table, series_type: mc.stype,
         "Gross domestic product: Current prices ;": mc.did, "$": mc.unit},
        verbose=False,
    )
    _, coe_id, _ = ra.find_abs_id(
        meta,
        {income_table: mc.table, series_type: mc.stype, "Compensation of employees ;": mc.did},
        exact=True, verbose=False,
    )
    gdp_cp = abs_dict[table][gdp_cp_id].dropna()
    coe = abs_dict[income_table][coe_id].dropna()

    calc_rulc = (coe / gdp_cp).dropna()           # real ULC proxy = labour share of nominal GDP
    calc_rulc_hma = hma(calc_rulc, hma_term)

    # ABS's own real ULC, formula applied, still current but annual only
    # (ASNA 5204.0). Map each financial year (ending June) to its June quarter so
    # it can sit on the quarterly axis.
    try:
        ann_dict, ann_meta = ra.read_abs_cat(
            "5204.0", single_excel_only="5204072_Unit_Labour_Costs", verbose=False
        )
        _, ann_id, _ = ra.find_abs_id(
            ann_meta, {"Real unit labour costs ;": mc.did}, exact=True, verbose=False
        )
        abs_annual = ann_dict["5204072_Unit_Labour_Costs"][ann_id].dropna()
        abs_annual.index = pd.PeriodIndex(
            [pd.Period(f"{p.year}Q2", freq="Q") for p in abs_annual.index]
        )
    except Exception as e:
        print(f"Could not fetch annual ABS ULC (5204.0): {e}")
        abs_annual = None

    if abs_rulc is not None:
        # rebase everything to 100 at the first quarter common to all the series
        # (the annual series starts in FY1986, so the common base is 1986Q2);
        # both calculated lines share the smooth base so they stay on one scale.
        idx = calc_rulc_hma.index.intersection(abs_rulc.index)
        if abs_annual is not None:
            idx = idx.intersection(abs_annual.index)
        base = idx.min()
        divisor = calc_rulc_hma.loc[base]

        cols = {
            "ABS Real ULC (quarterly Trend)": abs_rulc / abs_rulc.loc[base] * 100,
            "Calculated Real ULC (SA)": calc_rulc / divisor * 100,
            f"Calculated Real ULC ({hma_term}-term HMA)": calc_rulc_hma / divisor * 100,
        }
        width = [2.5, 0.8, 2.5]
        color = ["darkred", "silver", "navy"]
        style = ["-", "-", "--"]
        annotate = [True, False, True]
        if abs_annual is not None:
            cols["ABS Real ULC (annual, official 5204.0)"] = abs_annual / abs_annual.loc[base] * 100
            width.append(2.0)
            color.append("green")
            style.append("-")
            annotate.append(True)

        line_plot_finalise(
            pd.DataFrame(cols),
            title="Real Unit Labour Costs: Calculated vs ABS",
            ylabel=f"Index ({base} = 100)",
            width=width,
            color=color,
            style=style,
            marker=["", "", "", "o"] if abs_annual is not None else None,
            annotate=annotate,
            legend={"loc": "best", "fontsize": 8},
            rfooter=f"{source} {table} + {income_table} + ABS 5204.0",
            lfooter=(
                "Australia. ABS quarterly: Trend (ends 2019Q1); ABS annual: official "
                "(5204.0); Calculated: COE / nominal GDP, SA. "
            ),
            pre_tag="productivity-",
            tag="calc-vs-abs",
            show=SHOW,
            file_type=FILE_TYPE,
        )


# NOTE: The ABS discontinued the quarterly real unit labour cost series in 2019
# (it was Trend-only, and the ABS suspended quarterly trend estimates from 2019Q2
# during COVID), so the published series ends at 2019Q1.
# NOTE: It cannot be faithfully replicated from the published quarterly data:
# the ABS formula uses compensation of employees per *employee* hour over output
# per *total* hour, and economy-wide employee hours are not published quarterly.
# The ABS still applies its formula and publishes real ULC annually in 5204.0.
# These charts are disabled (set to True to regenerate them).
if False:
    real_unit_labour_costs()

# %% [markdown]
# ### Solow Residual (Multifactor Productivity)
#
# The Solow residual measures output growth not explained by growth in labour and capital inputs:
#
# $MFP = \frac{Y}{L^\alpha \cdot K^{1-\alpha}}$
#
# Where:
# - Y = Real GDP (chain volume measures)
# - L = Hours worked
# - K = Capital stock (estimated via perpetual inventory from GFCF)
# - α = Labour share of income (from COE / Total Factor Income)

# %%
def solow_residual() -> None:
    """Calculate and plot the Solow residual (Multifactor Productivity).
    
    MFP = Y / (L^α * K^(1-α))
    
    Uses:
    - GDP (CVM) for output
    - Hours worked for labour input
    - Capital stock from ABS Modellers Database (1364.0.15.003)
    - Labour share from COE / Total Factor Income
    """

    series_type = "Seasonally Adjusted"
    
    # --- Get GDP (Chain Volume Measures) ---
    gdp_table = KEY_AGGS
    selector = {
        gdp_table: mc.table,
        series_type: mc.stype,
        "Gross domestic product: Chain volume measures ;": mc.did,
        "$": mc.unit,
    }
    _table, gdp_id, _units = ra.find_abs_id(meta, selector, verbose=False)
    gdp = abs_dict[gdp_table][gdp_id].dropna()
    
    # --- Get Hours Worked (from Key Aggregates) ---
    hours_table = KEY_AGGS
    selector = {
        hours_table: mc.table,
        series_type: mc.stype,
        "Hours worked: Index ;": mc.did,
    }
    _table, hours_id, _units = ra.find_abs_id(meta, selector, verbose=False)
    hours = abs_dict[hours_table][hours_id].dropna()
    
    # --- Get Labour Share (COE / Total Factor Income) ---
    income_table = "5206007_Income_From_GDP"
    
    # Compensation of employees
    selector = {
        income_table: mc.table,
        series_type: mc.stype,
        "Compensation of employees ;": mc.did,
    }
    _table, coe_id, _units = ra.find_abs_id(meta, selector, exact=True, verbose=False)
    coe = abs_dict[income_table][coe_id].dropna()
    
    # Total factor income
    selector = {
        income_table: mc.table,
        series_type: mc.stype,
        "Total factor income ;": mc.did,
    }
    _table, tfi_id, _units = ra.find_abs_id(meta, selector, exact=True, verbose=False)
    tfi = abs_dict[income_table][tfi_id].dropna()
    
    # Labour share (alpha) - pandas handles alignment
    labour_share = (coe / tfi).dropna()
    
    # --- Get Capital Stock from ABS Modellers Database (1364.0.15.003) ---
    print("Fetching capital stock from ABS Modellers Database (1364.0.15.003)...")
    md_dict, md_meta = ra.read_abs_cat("1364.0.15.003")
    
    capital_did = "Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;"
    capital_rows = md_meta[
        (md_meta[mc.did] == capital_did) &
        (md_meta[mc.stype] == "Seasonally Adjusted")
    ]
    
    if len(capital_rows) == 0:
        # Try partial match
        capital_rows = md_meta[
            md_meta[mc.did].str.contains("Net capital stock", case=False, na=False) &
            md_meta[mc.did].str.contains("Chain volume", case=False, na=False) &
            (md_meta[mc.stype] == "Seasonally Adjusted")
        ]
    
    if len(capital_rows) == 0:
        print("Could not find capital stock series")
        return
        
    capital_row = capital_rows.iloc[0]
    capital_id = capital_row[mc.id]
    capital_table = capital_row[mc.table]
    capital = md_dict[capital_table][capital_id].dropna()
    print(f"Using: {capital_row[mc.did]}")
    
    # Use smoothed alpha (long-run average)
    alpha_smooth = labour_share.mean()
    
    # --- Normalize inputs to index form ---
    L_norm = hours / hours.iloc[0]
    K_norm = capital / capital.iloc[0]
    Y_norm = gdp / gdp.iloc[0]
    
    # --- Calculate Solow Residual (MFP) - pandas handles alignment ---
    # MFP = Y / (L^α * K^(1-α))
    mfp = (Y_norm / (L_norm ** alpha_smooth * K_norm ** (1 - alpha_smooth)) * 100).dropna()
    
    # --- Calculate MFP growth ---
    mfp_growth = mfp.pct_change(periods=4) * 100  # Annual growth
    mfp_growth = mfp_growth.dropna()
    
    # --- Apply smoothing filters ---
    # HP filter (lambda = 1600 for quarterly data)
    mfp_cycle, mfp_trend_hp = hpfilter(mfp, lamb=1600)
    mfp_trend_hp = pd.Series(mfp_trend_hp, index=mfp.index)
    
    # 13-term Henderson moving average
    mfp_trend_hma = hma(mfp, 13)
    
    # HP filter on growth
    growth_cycle, growth_trend_hp = hpfilter(mfp_growth, lamb=1600)
    growth_trend_hp = pd.Series(growth_trend_hp, index=mfp_growth.index)
    
    # 13-term Henderson on growth
    growth_trend_hma = hma(mfp_growth, 13)
    
    # --- Plotting ---
    common: dict[str, Any] = {
        "rfooter": f"{source} + ABS 1364.0.15.003",
        "lfooter": f"Australia. {series_type}. Calculated Solow residual. ",
        "pre_tag": "mfp-",
        "show": SHOW,
        "file_type": FILE_TYPE,
    }
    
    # Plot MFP level with trends
    mfp_df = pd.DataFrame({
        "MFP (Solow Residual)": mfp,
        "HP Filter Trend": mfp_trend_hp,
        "13-term Henderson MA": mfp_trend_hma,
    }).dropna()
    
    line_plot_finalise(
        mfp_df,
        title="Multifactor Productivity (Solow Residual)",
        ylabel="Index",
        width=[1, 2, 2],
        annotate=[False, False, True],
        legend={"loc": "best", "fontsize": 9},
        **common,
    )
    
    # Plot just the trends
    trends_df = pd.DataFrame({
        "HP Filter Trend": mfp_trend_hp,
        "13-term Henderson MA": mfp_trend_hma,
    }).dropna()
    
    line_plot_finalise(
        trends_df,
        title="MFP Trends: HP Filter vs Henderson MA",
        ylabel="Index",
        width=[2, 2],
        annotate=True,
        legend={"loc": "best", "fontsize": 9},
        tag="trends",
        **common,
    )
    
    # Plot MFP growth with trends
    growth_df = pd.DataFrame({
        "MFP Growth (YoY)": mfp_growth,
        "HP Filter Trend": growth_trend_hp,
        "13-term Henderson MA": growth_trend_hma,
    }).dropna()
    
    line_plot_finalise(
        growth_df,
        title="MFP Growth with Smoothed Trends",
        ylabel="Per cent (YoY)",
        width=[1, 2, 2],
        annotate=[False, False, True],
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="growth",
        **common,
    )
    
    # Plot comparison: Labour productivity vs MFP
    lp_selector = {
        KEY_AGGS: mc.table,
        series_type: mc.stype,
        "GDP per hour worked: Index ;": mc.did,
    }
    _table, lp_id, _units = ra.find_abs_id(meta, lp_selector, verbose=False)
    labour_prod = abs_dict[KEY_AGGS][lp_id].dropna()
    
    comparison_df = pd.DataFrame({
        "Labour Productivity": labour_prod,
        "MFP (Solow Residual)": mfp,
    }).dropna()
    # Rebase to 100 at the start of the visible data
    comparison_df = comparison_df / comparison_df.iloc[0] * 100
    
    line_plot_finalise(
        comparison_df,
        title="Labour Productivity vs Multifactor Productivity",
        width=2,
        ylabel=f"Index ({comparison_df.index[0]} = 100)",
        annotate=True,
        legend={"loc": "best", "fontsize": 9},
        tag="vs-lp",
        **common,
    )
    
    # Print summary statistics
    print(f"Labour share (α): {alpha_smooth:.3f}")
    print(f"MFP level (latest): {mfp.iloc[-1]:.1f}")
    print(f"MFP growth (latest YoY): {mfp_growth.iloc[-1]:.2f}%")
    print(f"MFP trend growth (HP, latest): {growth_trend_hp.iloc[-1]:.2f}%")
    print(f"MFP trend growth (HMA, latest): {growth_trend_hma.iloc[-1]:.2f}%")


solow_residual()
# Out:
# Fetching capital stock from ABS Modellers Database (1364.0.15.003)...
# Using: Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;
# Labour share (α): 0.545
# MFP level (latest): 142.6
# MFP growth (latest YoY): 0.74%
# MFP trend growth (HP, latest): -0.49%
# MFP trend growth (HMA, latest): 0.37%

# %% [markdown]
# ### GDP Growth Decomposition
#
# Decomposing GDP growth into contributions from labour, capital, and multifactor productivity:
#
# $$\Delta Y = \alpha \cdot \Delta L + (1-\alpha) \cdot \Delta K + \Delta MFP$$
#
# Where:
# - Y = Real GDP (chain volume measures)
# - L = Total labour force (from ABS Modellers Database 1364.0.15.003)
# - K = Capital stock (from ABS Modellers Database 1364.0.15.003)
# - α = Labour share of income (from COE / Total Factor Income)
# - MFP = Multifactor productivity (Solow residual)
#
# This decomposition shows how much of GDP growth comes from:
# 1. **Labour input growth** (more workers)
# 2. **Capital accumulation** (more machines/equipment)
# 3. **MFP growth** (doing more with the same inputs - technology, efficiency, etc.)
#
# Using employment rather than hours worked follows the original Solow model and allows the decomposition to extend back to 1959.

# %%
def gdp_growth_decomposition() -> None:
    """Decompose GDP growth into labour, capital, and MFP contributions.
    
    GDP growth = (1-α)(L growth) + α(K growth) + MFP growth
    
    Where α is the CAPITAL share (not labour share), following standard
    Cobb-Douglas convention: Y = A × K^α × L^(1-α)
    
    Uses data from ABS Modellers Database (1364.0.15.003) for:
    - Total labour force (L)
    - Net capital stock (K)
    
    Capital share α = GOS / (GOS + COE), using Total corporations GOS
    (excludes dwellings/imputed rent), typically ~0.30-0.34 for Australia
    """

    series_type = "Seasonally Adjusted"
    
    # --- Get GDP (Chain Volume Measures) from National Accounts ---
    gdp_selector = {
        KEY_AGGS: mc.table,
        series_type: mc.stype,
        "Gross domestic product: Chain volume measures ;": mc.did,
        "$": mc.unit,
    }
    _table, gdp_id, _units = ra.find_abs_id(meta, gdp_selector, verbose=False)
    gdp = abs_dict[KEY_AGGS][gdp_id].dropna()
    
    # --- Get Capital Share α = GOS / (GOS + COE) ---
    income_table = "5206007_Income_From_GDP"
    
    # Compensation of employees
    coe_selector = {
        income_table: mc.table,
        series_type: mc.stype,
        "Compensation of employees ;": mc.did,
    }
    _table, coe_id, _units = ra.find_abs_id(meta, coe_selector, exact=True, verbose=False)
    coe = abs_dict[income_table][coe_id].dropna()
    
    # Gross operating surplus - Total corporations (excludes dwellings/imputed rent)
    gos_selector = {
        income_table: mc.table,
        series_type: mc.stype,
        "Total corporations ;  Gross operating surplus ;": mc.did,
    }
    _table, gos_id, _units = ra.find_abs_id(meta, gos_selector, exact=True, verbose=False)
    gos = abs_dict[income_table][gos_id].dropna()
    
    # Capital share α = GOS / (GOS + COE)
    capital_share = (gos / (gos + coe)).dropna()
    alpha = capital_share.mean()  # Use long-run average
    
    # --- Fetch Labour Force and Capital from Modellers Database ---
    print("Fetching data from ABS Modellers Database (1364.0.15.003)...")
    md_dict, md_meta = ra.read_abs_cat("1364.0.15.003")
    
    # Labour force
    lf_rows = md_meta[
        (md_meta[mc.did] == "Total labour force ;") &
        (md_meta[mc.stype] == series_type)
    ]
    if len(lf_rows) == 0:
        print("Could not find Total labour force series")
        return
    lf_row = lf_rows.iloc[0]
    labour_force = md_dict[lf_row[mc.table]][lf_row[mc.id]].dropna()
    print(f"Labour force: {labour_force.index[0]} to {labour_force.index[-1]}")
    
    # Capital stock
    capital_rows = md_meta[
        (md_meta[mc.did] == "Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;") &
        (md_meta[mc.stype] == series_type)
    ]
    if len(capital_rows) == 0:
        capital_rows = md_meta[
            md_meta[mc.did].str.contains("Net capital stock", case=False, na=False) &
            md_meta[mc.did].str.contains("Chain volume", case=False, na=False) &
            (md_meta[mc.stype] == series_type)
        ]
    if len(capital_rows) == 0:
        print("Could not find capital stock series")
        return
    capital_row = capital_rows.iloc[0]
    capital = md_dict[capital_row[mc.table]][capital_row[mc.id]].dropna()
    print(f"Capital stock: {capital.index[0]} to {capital.index[-1]}")
    
    # --- Calculate growth rates (YoY) ---
    gdp_growth = gdp.pct_change(periods=4) * 100
    lf_growth = labour_force.pct_change(periods=4) * 100
    k_growth = capital.pct_change(periods=4) * 100
    
    # --- Calculate contributions ---
    # Using Cobb-Douglas: Y = A × K^α × L^(1-α), where α is CAPITAL share
    # Labour contribution = (1-α) × L growth
    labour_contrib = ((1 - alpha) * lf_growth).dropna()
    # Capital contribution = α × K growth  
    capital_contrib = (alpha * k_growth).dropna()
    
    # MFP contribution = GDP growth - Labour contrib - Capital contrib
    # First align all series
    contributions = pd.DataFrame({
        "GDP Growth": gdp_growth,
        "Labour Growth": labour_contrib,
        "Capital Growth": capital_contrib,
    }).dropna()
    
    contributions["MFP Growth"] = contributions["GDP Growth"] - contributions["Labour Growth"] - contributions["Capital Growth"]
    
    # --- Plotting ---
    # Use distinct colors: blue for Labour, darkorange for Capital, limegreen for MFP
    decomp_colors = ["#1f77b4", "darkorange", "limegreen"]
    
    # Footer text explaining methodology
    method_note = f"Solow growth accounting: ΔY = (1-α)ΔL + αΔK + ΔMFP, where α = {alpha:.2f} (capital share). "
    
    common: dict[str, Any] = {
        "rfooter": f"{source} + ABS 1364.0.15.003",
        "lfooter": f"Australia. {series_type}. {method_note}",
        "pre_tag": "gdp-decomp-",
        "show": SHOW,
        "file_type": FILE_TYPE,
        "color": decomp_colors,
    }
    
    # Contribution columns
    contrib_cols = ["Labour Growth", "Capital Growth", "MFP Growth"]
    contrib_df = contributions[contrib_cols]
    
    # Line chart showing contributions over time
    line_plot_finalise(
        contrib_df,
        title="GDP Growth Contributions (YoY)",
        ylabel="Percentage points",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="contributions",
        **common,
    )
    
    # Plot actual GDP growth vs sum of contributions (should match)
    check_df = pd.DataFrame({
        "GDP Growth (actual)": contributions["GDP Growth"],
        "Sum of contributions": contributions[contrib_cols].sum(axis=1),
    })
    
    line_plot_finalise(
        check_df,
        title="GDP Growth: Actual vs Decomposition",
        ylabel="Per cent (YoY)",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="check",
        rfooter=f"{source} + ABS 1364.0.15.003",
        lfooter=f"Australia. {series_type}. {method_note}",
        pre_tag="gdp-decomp-",
        show=SHOW,
        file_type=FILE_TYPE,
    )
    
    # Smoothed contributions (13-term Henderson MA with asymmetric end weights)
    hma_term = 13
    smoothed_hma = pd.DataFrame({
        col: hma(contributions[col], hma_term) for col in contrib_cols
    })
    
    line_plot_finalise(
        smoothed_hma,
        title=f"GDP Growth Contributions ({hma_term}-term Henderson MA)",
        ylabel="Percentage points",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="contributions-hma",
        **common,
    )
    
    # Smoothed contributions (Exponential Moving Average)
    # Span of 20 quarters (5 years) for smoother trend
    # EMA is one-sided (backward-looking only) so no endpoint revision
    ema_span = 20
    smoothed_ema = pd.DataFrame({
        col: contributions[col].ewm(span=ema_span, adjust=False).mean() 
        for col in contrib_cols
    })
    
    line_plot_finalise(
        smoothed_ema,
        title=f"GDP Growth Contributions (EMA, span={ema_span})",
        ylabel="Percentage points",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="contributions-ema",
        **common,
    )
    
    # Recent period (last 15 years)
    recent = contributions.iloc[-60:]
    line_plot_finalise(
        recent[contrib_cols],
        title="GDP Growth Contributions - Recent (YoY)",
        ylabel="Percentage points",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="contributions-recent",
        **common,
    )
    
    # --- Summary statistics ---
    print(f"\nCapital share (α): {alpha:.3f}")
    print(f"Labour share (1-α): {1-alpha:.3f}")
    print(f"\nLatest contributions (YoY):")
    print(f"  GDP Growth:     {contributions['GDP Growth'].iloc[-1]:.2f}%")
    print(f"  Labour Growth:  {contributions['Labour Growth'].iloc[-1]:.2f} pp")
    print(f"  Capital Growth: {contributions['Capital Growth'].iloc[-1]:.2f} pp")
    print(f"  MFP Growth:     {contributions['MFP Growth'].iloc[-1]:.2f} pp")
    
    print(f"\nLong-run average contributions:")
    print(f"  GDP Growth:     {contributions['GDP Growth'].mean():.2f}%")
    print(f"  Labour Growth:  {contributions['Labour Growth'].mean():.2f} pp")
    print(f"  Capital Growth: {contributions['Capital Growth'].mean():.2f} pp")
    print(f"  MFP Growth:     {contributions['MFP Growth'].mean():.2f} pp")


gdp_growth_decomposition()
# Out:
# Fetching data from ABS Modellers Database (1364.0.15.003)...
# Labour force: 1959Q3 to 2025Q4
# Capital stock: 1959Q3 to 2025Q4
# Capital share (α): 0.303
# Labour share (1-α): 0.697
#
# Latest contributions (YoY):
#   GDP Growth:     2.56%
#   Labour Growth:  1.02 pp
#   Capital Growth: 0.67 pp
#   MFP Growth:     0.87 pp
#
# Long-run average contributions:
#   GDP Growth:     3.32%
#   Labour Growth:  1.38 pp
#   Capital Growth: 1.41 pp
#   MFP Growth:     0.52 pp

# %% [markdown]
# ### Capital Stock: Perpetual Inventory vs ABS Modellers Database

# %%
def compare_capital_stock() -> None:
    """Compare perpetual inventory capital estimate with ABS Modellers Database."""

    series_type = "Seasonally Adjusted"
    
    # --- Calculate perpetual inventory capital (same as in solow_residual) ---
    gfcf_table = "5206002_Expenditure_Volume_Measures"
    selector = {
        gfcf_table: mc.table,
        series_type: mc.stype,
        "All sectors ;  Gross fixed capital formation ;": mc.did,
    }
    _table, gfcf_id, _units = ra.find_abs_id(meta, selector, verbose=False)
    gfcf = abs_dict[gfcf_table][gfcf_id].dropna()
    
    # Perpetual inventory method
    depreciation_rate = 0.025 / 4  # ~2.5% annual = 0.625% quarterly
    capital_pi = pd.Series(index=gfcf.index, dtype=float)
    capital_pi.iloc[0] = gfcf.iloc[0] * 40  # Initial estimate
    for i in range(1, len(gfcf)):
        capital_pi.iloc[i] = (1 - depreciation_rate) * capital_pi.iloc[i-1] + gfcf.iloc[i]
    
    # --- Fetch official capital stock from ABS Modellers Database (1364.0.15.003) ---
    print("Fetching ABS Modellers Database (1364.0.15.003)...")
    md_dict, md_meta = ra.read_abs_cat("1364.0.15.003")
    
    # Find the capital stock series
    capital_did = "Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;"
    capital_rows = md_meta[
        (md_meta[mc.did] == capital_did) &
        (md_meta[mc.stype] == "Seasonally Adjusted")
    ]
    
    if len(capital_rows) == 0:
        # Try partial match
        capital_rows = md_meta[
            md_meta[mc.did].str.contains("Net capital stock", case=False, na=False) &
            md_meta[mc.did].str.contains("Chain volume", case=False, na=False) &
            (md_meta[mc.stype] == "Seasonally Adjusted")
        ]
    
    if len(capital_rows) == 0:
        print("Could not find capital stock series. Available series:")
        print(md_meta[mc.did].unique()[:20])
        return
    
    capital_row = capital_rows.iloc[0]
    capital_id = capital_row[mc.id]
    capital_table = capital_row[mc.table]
    capital_units = capital_row[mc.unit]
    
    capital_abs = md_dict[capital_table][capital_id].dropna()
    print(f"Found: {capital_row[mc.did]}")
    print(f"Units: {capital_units}")
    print(f"Period: {capital_abs.index[0]} to {capital_abs.index[-1]}")
    
    common: dict[str, Any] = {
        "rfooter": f"{source} + ABS 1364.0.15.003",
        "lfooter": f"Australia. {series_type}. PI assumes 2.5% p.a. depreciation. ",
        "pre_tag": "capital-comparison-",
        "show": SHOW,
        "file_type": FILE_TYPE,
    }
    
    # --- Plot levels ---
    comparison_df = pd.DataFrame({
        "Perpetual Inventory (from GFCF)": capital_pi,
        "ABS Modellers Database": capital_abs,
    }).dropna()
    comparison_df, units = ra.recalibrate(comparison_df, capital_units)
    
    line_plot_finalise(
        comparison_df,
        title="Capital Stock: Perpetual Inventory vs ABS Official",
        ylabel=units,
        annotate=True,
        legend={"loc": "best", "fontsize": 9},
        **common,
    )
    
    # --- Plot growth rates ---
    pi_growth = capital_pi.pct_change(periods=4) * 100
    abs_growth = capital_abs.pct_change(periods=4) * 100
    
    growth_df = pd.DataFrame({
        "Perpetual Inventory": pi_growth,
        "ABS Modellers Database": abs_growth,
    }).dropna()
    
    line_plot_finalise(
        growth_df,
        title="Capital Stock Growth (YoY): PI vs ABS Official",
        ylabel="Per cent",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="growth",
        **common,
    )
    
    # --- Plot rebased index comparison ---
    pi_rebased = capital_pi / capital_pi.iloc[0] * 100
    abs_rebased = capital_abs / capital_abs.iloc[0] * 100
    
    index_df = pd.DataFrame({
        "Perpetual Inventory": pi_rebased,
        "ABS Modellers Database": abs_rebased,
    }).dropna()
    
    line_plot_finalise(
        index_df,
        title="Capital Stock Index: PI vs ABS Official",
        ylabel="Index (start = 100)",
        annotate=True,
        legend={"loc": "best", "fontsize": 9},
        tag="index",
        **common,
    )
    
    # --- Summary statistics ---
    correlation = comparison_df.iloc[:, 0].corr(comparison_df.iloc[:, 1])
    growth_corr = growth_df.iloc[:, 0].corr(growth_df.iloc[:, 1])
    print(f"\nCorrelation (levels): {correlation:.4f}")
    print(f"Correlation (growth): {growth_corr:.4f}")
    print(f"PI latest: {comparison_df.iloc[-1, 0]:.1f} {units}")
    print(f"ABS latest: {comparison_df.iloc[-1, 1]:.1f} {units}")
    print(f"Ratio (PI/ABS): {comparison_df.iloc[-1, 0] / comparison_df.iloc[-1, 1]:.3f}")


compare_capital_stock()
# Out:
# Fetching ABS Modellers Database (1364.0.15.003)...
# Found: Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;
# Units: $ Millions
# Period: 1959Q3 to 2025Q4
# Correlation (levels): 0.9971
# Correlation (growth): 0.9671
# PI latest: 12.2 $ Trillions
# ABS latest: 3.9 $ Trillions
# Ratio (PI/ABS): 3.094

# %% [markdown]
# ### Capital Stock Growth and Capital Deepening
#
# Capital deepening measures capital per hour worked (K/L), showing how much capital each unit of labour has available. Rising capital deepening typically supports labour productivity growth.

# %%
def capital_stock_and_deepening() -> None:
    """Plot capital stock growth and capital deepening (K/L)."""

    series_type = "Seasonally Adjusted"
    
    # --- Fetch capital stock from ABS Modellers Database (1364.0.15.003) ---
    print("Fetching capital stock from ABS Modellers Database (1364.0.15.003)...")
    md_dict, md_meta = ra.read_abs_cat("1364.0.15.003")
    
    capital_did = "Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;"
    capital_rows = md_meta[
        (md_meta[mc.did] == capital_did) &
        (md_meta[mc.stype] == "Seasonally Adjusted")
    ]
    
    if len(capital_rows) == 0:
        capital_rows = md_meta[
            md_meta[mc.did].str.contains("Net capital stock", case=False, na=False) &
            md_meta[mc.did].str.contains("Chain volume", case=False, na=False) &
            (md_meta[mc.stype] == "Seasonally Adjusted")
        ]
    
    if len(capital_rows) == 0:
        print("Could not find capital stock series")
        return
    
    capital_row = capital_rows.iloc[0]
    capital_id = capital_row[mc.id]
    capital_table = capital_row[mc.table]
    capital = md_dict[capital_table][capital_id].dropna()
    print(f"Using: {capital_row[mc.did]}")
    
    # --- Get Hours Worked (from Key Aggregates) ---
    hours_selector = {
        KEY_AGGS: mc.table,
        series_type: mc.stype,
        "Hours worked: Index ;": mc.did,
    }
    _table, hours_id, _units = ra.find_abs_id(meta, hours_selector, verbose=False)
    hours = abs_dict[KEY_AGGS][hours_id].dropna()
    
    common: dict[str, Any] = {
        "rfooter": f"ABS 1364.0.15.003 (Modeller's Database)",
        "lfooter": f"Australia. {series_type}. ",
        "pre_tag": "capital-",
        "show": SHOW,
        "file_type": FILE_TYPE,
    }
    
    # --- Capital Stock Growth ---
    capital_growth = capital.pct_change(periods=4) * 100
    capital_growth = capital_growth.dropna()
    capital_growth.name = "Capital Stock Growth"
    
    # Apply Henderson smoothing
    hma_term = 13
    capital_growth_hma = hma(capital_growth, hma_term)
    
    growth_df = pd.DataFrame({
        "Annual growth": capital_growth,
        f"{hma_term}-term HMA": capital_growth_hma,
    })
    
    line_plot_finalise(
        growth_df,
        title="Capital Stock Growth (Net, Chain Volume Measures)",
        ylabel="Per cent (YoY)",
        width=[1, 3],
        annotate=[False, True],
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="growth",
        **common,
    )
    
    # Recent history
    line_plot_finalise(
        growth_df.iloc[-60:],
        title="Capital Stock Growth (Net, Chain Volume Measures)",
        ylabel="Per cent (YoY)",
        width=[1, 3],
        annotate=[False, True],
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="growth-recent",
        **common,
    )
    
    # --- Capital Deepening (K/L) ---
    # Normalize both to index form
    K_norm = capital / capital.iloc[0] * 100
    L_norm = hours / hours.iloc[0] * 100
    
    # Capital deepening = K/L (indexed) - pandas handles alignment
    capital_deepening = (K_norm / L_norm * 100).dropna()
    capital_deepening.name = "Capital Deepening (K/L)"
    
    common_kl: dict[str, Any] = {
        "rfooter": f"ABS 1364.0.15.003 + {source}",
        "lfooter": f"Australia. {series_type}. Capital per hour worked (indexed). ",
        "pre_tag": "capital-deepening-",
        "show": SHOW,
        "file_type": FILE_TYPE,
    }
    
    # Level chart
    multi_start(
        capital_deepening,
        function=line_plot_finalise,
        starts=line_starts,
        title="Capital Deepening (Capital per Hour Worked)",
        ylabel=f"Index ({capital_deepening.index[0]} = 100)",
        annotate=True,
        **common_kl,
    )
    
    # Growth chart
    kl_growth = capital_deepening.pct_change(periods=4) * 100
    kl_growth = kl_growth.dropna()
    kl_growth_hma = hma(kl_growth, hma_term)
    
    kl_growth_df = pd.DataFrame({
        "Annual growth": kl_growth,
        f"{hma_term}-term HMA": kl_growth_hma,
    })
    
    line_plot_finalise(
        kl_growth_df,
        title="Capital Deepening Growth",
        ylabel="Per cent (YoY)",
        width=[1, 3],
        annotate=[False, True],
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="growth",
        **common_kl,
    )
    
    # --- Hours Worked Index (same timescale as capital deepening) ---
    # Rebase hours to start at 100 at beginning of capital deepening series
    hours_aligned = hours.loc[capital_deepening.index[0]:].copy()
    hours_index = hours_aligned / hours_aligned.iloc[0] * 100
    hours_index.name = "Hours Worked"
    
    line_plot_finalise(
        hours_index,
        title="Hours Worked",
        ylabel=f"Index ({hours_index.index[0]} = 100)",
        annotate=True,
        rfooter=f"{source}",
        lfooter=f"Australia. {series_type}. Total hours worked in the economy. ",
        pre_tag="hours-worked-",
        show=SHOW,
        file_type=FILE_TYPE,
    )
    
    # --- Comparison: Capital Deepening vs Labour Productivity ---
    lp_selector = {
        KEY_AGGS: mc.table,
        series_type: mc.stype,
        "GDP per hour worked: Index ;": mc.did,
    }
    _table, lp_id, _units = ra.find_abs_id(meta, lp_selector, verbose=False)
    labour_prod = abs_dict[KEY_AGGS][lp_id].dropna()
    labour_prod_norm = labour_prod / labour_prod.iloc[0] * 100
    
    comparison_df = pd.DataFrame({
        "Capital Deepening (K/L)": capital_deepening,
        "Labour Productivity (Y/L)": labour_prod_norm,
    }).dropna()
    
    line_plot_finalise(
        comparison_df,
        title="Capital Deepening vs Labour Productivity",
        ylabel="Index (start = 100)",
        annotate=True,
        legend={"loc": "best", "fontsize": 9},
        tag="vs-productivity",
        **common_kl,
    )
    
    # Growth comparison
    lp_growth = labour_prod_norm.pct_change(periods=4) * 100
    growth_compare = pd.DataFrame({
        "Capital Deepening": kl_growth,
        "Labour Productivity": lp_growth,
    }).dropna()
    
    line_plot_finalise(
        growth_compare,
        title="Capital Deepening vs Labour Productivity Growth",
        ylabel="Per cent (YoY)",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="growth-vs-productivity",
        **common_kl,
    )
    
    print(f"Capital deepening (latest): {capital_deepening.iloc[-1]:.1f}")
    print(f"Capital deepening growth (latest YoY): {kl_growth.iloc[-1]:.2f}%")
    print(f"Hours worked index (latest): {hours_index.iloc[-1]:.1f}")


capital_stock_and_deepening()
# Out:
# Fetching capital stock from ABS Modellers Database (1364.0.15.003)...
# Using: Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;
# Capital deepening (latest): 921.4
# Capital deepening growth (latest YoY): 0.73%
# Hours worked index (latest): 219.1

# %% [markdown]
# ### Decade-average helper
#
# Shared helper for the decade-average step charts below. Takes a YoY-growth
# series and overlays a step line of decade-average growth, for either calendar
# decades (years ending 0-9) or buckets running year-ending-6 to year-ending-5.

# %%
# === Decade-average step-overlay helper ===
def decade_average_plot(
    growth,
    *,
    title: str,
    rfooter: str,
    lfooter: str,
    pre_tag: str,
    tag: str,
    six_to_five: bool = False,
) -> None:
    """Plot a YoY-growth series with a decade-average step line.

    six_to_five=False uses calendar decades (years ending 0-9);
    six_to_five=True uses buckets running year-ending-6 to year-ending-5.
    """
    if six_to_five:
        def bucket(year: int) -> int:
            return ((year - 6) // 10) * 10 + 6
        avg_name = "Decade average (6-to-5)"
    else:
        def bucket(year: int) -> int:
            return (year // 10) * 10
        avg_name = "Decade average"

    labels = pd.Series([bucket(p.year) for p in growth.index], index=growth.index)
    avgs = growth.groupby(labels).mean()
    step = pd.Series(
        [avgs.loc[bucket(p.year)] for p in growth.index],
        index=growth.index,
        name=avg_name,
    )

    line_plot_finalise(
        pd.DataFrame({"Annual growth (YoY)": growth, avg_name: step}),
        title=title,
        ylabel="Per cent (YoY)",
        width=[1, 3],
        color=["#888888", "darkred"],
        style=["-", "-"],
        annotate=[False, True],
        rounding=2,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        rfooter=rfooter,
        lfooter=lfooter,
        pre_tag=pre_tag,
        tag=tag,
        show=SHOW,
        file_type=FILE_TYPE,
    )

# %% [markdown]
# ### Capital Deepening with Decade Averages
#
# Companion view of capital deepening YoY growth, with a step line showing
# the decade-average growth rate. Same underlying data as the chart above
# (K from 1364.0.15.003 SA, L from 5206 hours-worked index SA).

# %%
def capital_deepening_decade_averages() -> None:
    """Capital deepening YoY growth with decade-average step overlay."""

    series_type = "Seasonally Adjusted"

    md_dict, md_meta = ra.read_abs_cat("1364.0.15.003", verbose=False)
    capital_did = (
        "Non-financial and financial corporations ; "
        "Net capital stock (Chain volume measures) ;"
    )
    rows = md_meta[
        (md_meta[mc.did] == capital_did) & (md_meta[mc.stype] == series_type)
    ]
    if len(rows) == 0:
        print("Could not find capital stock series")
        return
    cap_row = rows.iloc[0]
    capital = md_dict[cap_row[mc.table]][cap_row[mc.id]].dropna()

    _, hours_id, _ = ra.find_abs_id(
        meta,
        {KEY_AGGS: mc.table, series_type: mc.stype, "Hours worked: Index ;": mc.did},
        verbose=False,
    )
    hours = abs_dict[KEY_AGGS][hours_id].dropna()

    K_norm = capital / capital.iloc[0] * 100
    L_norm = hours / hours.iloc[0] * 100
    capital_deepening = (K_norm / L_norm * 100).dropna()
    kl_growth = (capital_deepening.pct_change(periods=4) * 100).dropna()

    decade_average_plot(
        kl_growth,
        title="Capital Deepening Growth with Decade Averages",
        rfooter=f"ABS 1364.0.15.003 + {source}",
        lfooter=f"Australia. {series_type}. Capital per hour worked, YoY growth.",
        pre_tag="capital-deepening-",
        tag="decade-averages",
        six_to_five=False,
    )


capital_deepening_decade_averages()

# %% [markdown]
# ### Capital Deepening with Decade Averages (Years Ending 6 to 5)
#
# Same data, but with decade buckets shifted to run from a year ending in 6
# to a year ending in 5 inclusive: 1986-1995, 1996-2005, 2006-2015, 2016-2025.
# This framing aligns the buckets with the post-mining-boom slowdown.

# %%
def capital_deepening_decade_averages_6to5() -> None:
    """Capital deepening YoY growth with decade-average step overlay,
    using decade buckets that run year-ending-6 to year-ending-5 inclusive."""

    series_type = "Seasonally Adjusted"

    md_dict, md_meta = ra.read_abs_cat("1364.0.15.003", verbose=False)
    capital_did = (
        "Non-financial and financial corporations ; "
        "Net capital stock (Chain volume measures) ;"
    )
    rows = md_meta[
        (md_meta[mc.did] == capital_did) & (md_meta[mc.stype] == series_type)
    ]
    if len(rows) == 0:
        print("Could not find capital stock series")
        return
    cap_row = rows.iloc[0]
    capital = md_dict[cap_row[mc.table]][cap_row[mc.id]].dropna()

    _, hours_id, _ = ra.find_abs_id(
        meta,
        {KEY_AGGS: mc.table, series_type: mc.stype, "Hours worked: Index ;": mc.did},
        verbose=False,
    )
    hours = abs_dict[KEY_AGGS][hours_id].dropna()

    K_norm = capital / capital.iloc[0] * 100
    L_norm = hours / hours.iloc[0] * 100
    capital_deepening = (K_norm / L_norm * 100).dropna()
    kl_growth = (capital_deepening.pct_change(periods=4) * 100).dropna()

    decade_average_plot(
        kl_growth,
        title="Capital Deepening Growth with Decade Averages (6-to-5)",
        rfooter=f"ABS 1364.0.15.003 + {source}",
        lfooter=f"Australia. {series_type}. Capital per hour worked, YoY growth. Decades: years ending 6 to 5.",
        pre_tag="capital-deepening-",
        tag="decade-averages-6to5",
        six_to_five=True,
    )


capital_deepening_decade_averages_6to5()

# %% [markdown]
# ### Labour Productivity with Decade Averages
#
# Annual (YoY) growth in labour productivity (GDP per hour worked, SA from the
# 5206 Key Aggregates table), with a step line of decade-average growth. Two
# framings (companion to the capital-deepening charts above): calendar decades
# (years ending 0-9) and buckets running year-ending-6 to year-ending-5. Either
# way it lays out the productivity slowdown - the 1990s / 1996-2005 peak, then
# each decade steps down toward ~0.3% most recently.

# %%
# === Labour Productivity Growth with Decade Averages ===
def labour_productivity_decade_averages() -> None:
    """Labour productivity (GDP per hour worked) YoY growth with decade-average
    step overlays, for calendar decades (0-9) and 6-to-5 buckets."""

    series_type = "Seasonally Adjusted"
    _, lp_id, _ = ra.find_abs_id(
        meta,
        {KEY_AGGS: mc.table, series_type: mc.stype, "GDP per hour worked: Index ;": mc.did},
        verbose=False,
    )
    lp_growth = (abs_dict[KEY_AGGS][lp_id].dropna().pct_change(periods=4) * 100).dropna()

    decade_average_plot(
        lp_growth,
        title="Labour Productivity Growth with Decade Averages",
        rfooter=source,
        lfooter=f"Australia. {series_type}. GDP per hour worked, YoY growth.",
        pre_tag="labour-productivity-",
        tag="decade-averages",
        six_to_five=False,
    )
    decade_average_plot(
        lp_growth,
        title="Labour Productivity Growth with Decade Averages (6-to-5)",
        rfooter=source,
        lfooter=f"Australia. {series_type}. GDP per hour worked, YoY growth. Decades: years ending 6 to 5.",
        pre_tag="labour-productivity-",
        tag="decade-averages-6to5",
        six_to_five=True,
    )


labour_productivity_decade_averages()

# %% [markdown]
# ### Labour Productivity with 10-Year Moving Average
#
# Annual (YoY) growth in labour productivity (GDP per hour worked, SA from the
# 5206 Key Aggregates table), with a 10-year (40-quarter) moving average showing
# the long-run trend. The moving average peaks around the early 2000s and trends
# down to ~0.3% most recently.

# %%
# === Labour Productivity Growth with 10-Year Moving Average ===
def labour_productivity_10yr_ma() -> None:
    """Labour productivity (GDP per hour worked) YoY growth with a 10-year moving average."""

    series_type = "Seasonally Adjusted"
    _, lp_id, _ = ra.find_abs_id(
        meta,
        {KEY_AGGS: mc.table, series_type: mc.stype, "GDP per hour worked: Index ;": mc.did},
        verbose=False,
    )
    lp_growth = (abs_dict[KEY_AGGS][lp_id].dropna().pct_change(periods=4) * 100).dropna()
    moving_avg = lp_growth.rolling(window=40, min_periods=40).mean()  # 10 years = 40 quarters

    plot_df = pd.DataFrame({
        "Annual growth (YoY)": lp_growth,
        "10-year moving average": moving_avg,
    })

    line_plot_finalise(
        plot_df,
        title="Labour Productivity Growth with 10-Year Moving Average",
        ylabel="Per cent (YoY)",
        width=[1, 3],
        color=["#888888", "navy"],
        style=["-", "-"],
        annotate=[False, True],
        rounding=2,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        rfooter=source,
        lfooter=f"Australia. {series_type}. GDP per hour worked, YoY growth. 10-year (40-quarter) moving average.",
        pre_tag="labour-productivity-",
        tag="10yr-ma",
        show=SHOW,
        file_type=FILE_TYPE,
    )


labour_productivity_10yr_ma()

# %% [markdown]
# ### Capital Productivity
#
# Capital productivity measures **output per unit of capital (Y/K)** — essentially how efficiently capital is being used to produce output. The inverse (K/Y) is the capital-output ratio, which shows how much capital is needed to produce one unit of output.
#
# **Relationship between productivity measures:**
#
# | Measure | Formula | Interpretation |
# |---------|---------|----------------|
# | Labour productivity | Y/L | Output per hour worked |
# | Capital productivity | Y/K | Output per unit of capital |
# | Capital deepening | K/L | Capital per hour worked |
# | MFP (Solow residual) | Y / (L^α × K^(1-α)) | Efficiency of combined inputs |
#
# These measures are related by the identity:
#
# **Labour productivity = Capital deepening × Capital productivity**
#
# Or: `Y/L = (K/L) × (Y/K)`
#
# Capital productivity often **declines** during periods of heavy investment (capital deepening) as new capital takes time to become fully productive. One of Kaldor's "stylized facts" of growth is that the capital-output ratio tends to be relatively stable over the long run, implying stable capital productivity in trend terms.

# %%
def capital_productivity() -> None:
    """Plot capital productivity (Y/K) and capital-output ratio (K/Y)."""

    series_type = "Seasonally Adjusted"
    
    # --- Get GDP (Chain Volume Measures) ---
    gdp_selector = {
        KEY_AGGS: mc.table,
        series_type: mc.stype,
        "Gross domestic product: Chain volume measures ;": mc.did,
        "$": mc.unit,
    }
    _table, gdp_id, _units = ra.find_abs_id(meta, gdp_selector, verbose=False)
    gdp = abs_dict[KEY_AGGS][gdp_id].dropna()
    
    # --- Fetch capital stock from ABS Modellers Database (1364.0.15.003) ---
    print("Fetching capital stock from ABS Modellers Database (1364.0.15.003)...")
    md_dict, md_meta = ra.read_abs_cat("1364.0.15.003")
    
    capital_did = "Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;"
    capital_rows = md_meta[
        (md_meta[mc.did] == capital_did) &
        (md_meta[mc.stype] == "Seasonally Adjusted")
    ]
    
    if len(capital_rows) == 0:
        capital_rows = md_meta[
            md_meta[mc.did].str.contains("Net capital stock", case=False, na=False) &
            md_meta[mc.did].str.contains("Chain volume", case=False, na=False) &
            (md_meta[mc.stype] == "Seasonally Adjusted")
        ]
    
    if len(capital_rows) == 0:
        print("Could not find capital stock series")
        return
    
    capital_row = capital_rows.iloc[0]
    capital_id = capital_row[mc.id]
    capital_table = capital_row[mc.table]
    capital = md_dict[capital_table][capital_id].dropna()
    print(f"Using: {capital_row[mc.did]}")
    
    # --- Get Hours Worked (from Key Aggregates) ---
    hours_selector = {
        KEY_AGGS: mc.table,
        series_type: mc.stype,
        "Hours worked: Index ;": mc.did,
    }
    _table, hours_id, _units = ra.find_abs_id(meta, hours_selector, verbose=False)
    hours = abs_dict[KEY_AGGS][hours_id].dropna()
    
    # --- Normalize to index form ---
    Y_norm = gdp / gdp.iloc[0] * 100
    K_norm = capital / capital.iloc[0] * 100
    L_norm = hours / hours.iloc[0] * 100
    
    # --- Capital Productivity (Y/K) - pandas handles alignment ---
    capital_prod = (Y_norm / K_norm * 100).dropna()
    capital_prod.name = "Capital Productivity (Y/K)"
    
    common: dict[str, Any] = {
        "rfooter": f"{source} + ABS 1364.0.15.003",
        "lfooter": f"Australia. {series_type}. Output per unit of capital (indexed). ",
        "pre_tag": "capital-productivity-",
        "show": SHOW,
        "file_type": FILE_TYPE,
    }
    
    # Level charts
    multi_start(
        capital_prod,
        function=line_plot_finalise,
        starts=line_starts,
        title="Capital Productivity (Output per Unit of Capital)",
        ylabel=f"Index ({capital_prod.index[0]} = 100)",
        annotate=True,
        **common,
    )
    
    # Growth chart
    hma_term = 13
    cp_growth = capital_prod.pct_change(periods=4) * 100
    cp_growth = cp_growth.dropna()
    cp_growth_hma = hma(cp_growth, hma_term)
    
    growth_df = pd.DataFrame({
        "Annual growth": cp_growth,
        f"{hma_term}-term HMA": cp_growth_hma,
    })
    
    line_plot_finalise(
        growth_df,
        title="Capital Productivity Growth",
        ylabel="Per cent (YoY)",
        width=[1, 3],
        annotate=[False, True],
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="growth",
        **common,
    )
    
    # --- Capital-Output Ratio (K/Y) ---
    capital_output_ratio = (K_norm / Y_norm * 100).dropna()
    capital_output_ratio.name = "Capital-Output Ratio (K/Y)"
    
    common_ky: dict[str, Any] = {
        "rfooter": f"{source} + ABS 1364.0.15.003",
        "lfooter": f"Australia. {series_type}. Real K / Real Y (both CVM). ",
        "pre_tag": "capital-output-ratio-",
        "show": SHOW,
        "file_type": FILE_TYPE,
    }
    
    multi_start(
        capital_output_ratio,
        function=line_plot_finalise,
        starts=line_starts,
        title="Capital-Output Ratio (Capital per Unit of Output)",
        ylabel=f"Index ({capital_output_ratio.index[0]} = 100)",
        annotate=True,
        **common_ky,
    )
    
    # --- Comparison: All three productivity measures ---
    labour_prod = (Y_norm / L_norm * 100).dropna()
    capital_deepening = (K_norm / L_norm * 100).dropna()
    
    comparison_df = pd.DataFrame({
        "Labour Productivity (Y/L)": labour_prod,
        "Capital Deepening (K/L)": capital_deepening,
        "Capital Productivity (Y/K)": capital_prod,
    }).dropna()
    
    # Rebase to 100 at the start of the visible (common) data
    comparison_df = comparison_df / comparison_df.iloc[0] * 100
    
    line_plot_finalise(
        comparison_df,
        title="Productivity Measures Comparison",
        width=2,
        ylabel=f"Index ({comparison_df.index[0]} = 100)",
        annotate=True,
        legend={"loc": "best", "fontsize": 9},
        tag="comparison",
        lfooter=f"Australia. {series_type}. L = hours worked. Y/L = (K/L) × (Y/K). ",
        rfooter=f"{source} + ABS 1364.0.15.003",
        pre_tag="capital-productivity-",
        show=SHOW,
        file_type=FILE_TYPE,
    )
    
    # Growth comparison
    lp_growth = labour_prod.pct_change(periods=4) * 100
    kl_growth = capital_deepening.pct_change(periods=4) * 100
    
    growth_compare = pd.DataFrame({
        "Labour Productivity (Y/L)": lp_growth,
        "Capital Deepening (K/L)": kl_growth,
        "Capital Productivity (Y/K)": cp_growth,
    }).dropna()
    
    line_plot_finalise(
        growth_compare,
        title="Productivity Growth Comparison",
        ylabel="Per cent (YoY)",
        annotate=True,
        y0=True,
        legend={"loc": "best", "fontsize": 9},
        tag="growth-comparison",
        lfooter=f"Australia. {series_type}. L = hours worked. ",
        rfooter=f"{source} + ABS 1364.0.15.003",
        pre_tag="capital-productivity-",
        show=SHOW,
        file_type=FILE_TYPE,
    )
    
    print(f"Capital productivity (latest): {capital_prod.iloc[-1]:.1f}")
    print(f"Capital productivity growth (latest YoY): {cp_growth.iloc[-1]:.2f}%")
    print(f"Capital-output ratio (latest): {capital_output_ratio.iloc[-1]:.1f}")


capital_productivity()
# Out:
# Fetching capital stock from ABS Modellers Database (1364.0.15.003)...
# Using: Non-financial and financial corporations ; Net capital stock (Chain volume measures) ;
# Capital productivity (latest): 42.5
# Capital productivity growth (latest YoY): 0.34%
# Capital-output ratio (latest): 235.2

# %% [markdown]
# ### Market Sector Labour Productivity by Industry

# %%
def market_sector_productivity_by_industry() -> None:
    """Real GVA per hour worked, indexed, for each market-sector industry.

    GVA (chain volume, seasonally adjusted) comes from 5206.0 table
    5206006_Industry_GVA; hours actually worked by industry come from the
    quarterly Labour Account (6150.0.55.003), one table per division. The
    market sector is ANZSIC divisions A-N plus R and S - it excludes Public
    administration (O), Education (P), Health (Q) and Ownership of dwellings.
    """

    gva_table = "5206006_Industry_GVA"
    series_type = "Seasonally Adjusted"
    hma_term = 13
    hours_did = "Labour Account hours actually worked in all jobs"

    # division letter -> (legend name, Labour Account table)
    market = {
        "A": ("Agriculture", "6150055003DO002"),
        "B": ("Mining", "6150055003DO003"),
        "C": ("Manufacturing", "6150055003DO004"),
        "D": ("Electricity, gas & water", "6150055003DO005"),
        "E": ("Construction", "6150055003DO006"),
        "F": ("Wholesale trade", "6150055003DO007"),
        "G": ("Retail trade", "6150055003DO008"),
        "H": ("Accommodation & food", "6150055003DO009"),
        "I": ("Transport", "6150055003DO010"),
        "J": ("Info media & telco", "6150055003DO011"),
        "K": ("Finance & insurance", "6150055003DO012"),
        "L": ("Rental & real estate", "6150055003DO013"),
        "M": ("Professional & technical", "6150055003DO014"),
        "N": ("Admin & support", "6150055003DO015"),
        "R": ("Arts & recreation", "6150055003DO019"),
        "S": ("Other services", "6150055003DO020"),
    }

    # Hours actually worked by industry - quarterly Labour Account.
    # Fetched separately so it does not disturb this notebook's chart dir.
    hours_cat = "6150.0.55.003"
    hours_dict, hours_meta = ra.read_abs_cat(hours_cat, verbose=False)

    gva_data = abs_dict[gva_table]
    productivity = {}
    for letter, (name, hours_table) in market.items():
        # GVA division total (level, $m CVM): the DID ends in "(<letter>) ;",
        # which excludes the sub-division and percentage-change variants.
        gva_rows = meta[
            (meta[mc.table] == gva_table)
            & (meta[mc.stype] == series_type)
            & (meta[mc.did].str.contains(rf"\({letter}\) ;$", regex=True))
        ]
        # Hours actually worked for this industry (one table per division).
        hours_rows = hours_meta[
            (hours_meta[mc.table] == hours_table)
            & (hours_meta[mc.stype] == series_type)
            & (hours_meta[mc.did].str.contains(hours_did, regex=False))
            & (~hours_meta[mc.did].str.contains("Percentage", regex=False))
        ]
        if len(gva_rows) != 1 or len(hours_rows) != 1:
            print(f"Skipping {name}: gva={len(gva_rows)} hours={len(hours_rows)} rows")
            continue

        gva = gva_data[gva_rows[mc.id].iloc[0]].dropna()
        hours = hours_dict[hours_table][hours_rows[mc.id].iloc[0]].dropna()

        # Real GVA per hour worked, Henderson-smoothed, then indexed to 100.
        prod = (gva / hours).dropna()
        prod = hma(prod, hma_term)
        productivity[name] = prod / prod.iloc[0] * 100

    if not productivity:
        print("No industry productivity series built")
        return

    df = pd.DataFrame(productivity)
    base = df.index[0]
    # append each industry's latest index value to its legend label
    df.columns = [f"{c} ({df[c].iloc[-1]:.0f})" for c in df.columns]

    # 16 distinct colours; line style varied in blocks so similar hues stay apart
    colors = [
        "#000000", "#e6194B", "#3cb44b", "#4363d8",
        "#f58231", "#911eb4", "#008080", "#f032e6",
        "#9A6324", "#808000", "#000075", "#800000",
        "#42d4f4", "#DAA520", "#808080", "#1f9e89",
    ]
    styles = ["-"] * 4 + ["--"] * 4 + ["-."] * 4 + [":"] * 4

    line_plot_finalise(
        df,
        title="Market Sector Labour Productivity by Industry",
        ylabel=f"Index ({base} = 100)",
        figsize=(9.0, 9.0),
        width=2,
        color=colors,
        style=styles,
        annotate=True,
        rounding=0,
        fontsize="x-small",
        axhline={"y": 100, "color": "black", "linewidth": 0.75, "alpha": 0.7},
        legend={"loc": "upper left", "fontsize": 8, "ncol": 2},
        rfooter=f"{source} + ABS {hours_cat}",
        lfooter=f"Australia. {series_type}. Real GVA per hour worked, {hma_term}-term Henderson MA. ",
        pre_tag="productivity-",
        show=SHOW,
        file_type=FILE_TYPE,
    )


market_sector_productivity_by_industry()
# Out:
# Table Labour Account by sex and age group Total all industries has no 'Index' sheet.
# Table Labour Account by sex and age group by Industry has no 'Index' sheet.

# %% [markdown]
# ## Watermark

# %%
# watermark
# %load_ext watermark
# %watermark -u -t -d --iversions --watermark --machine --python --conda
# Out:
# Last updated: 2026-05-30 07:49:45
#
# Python implementation: CPython
# Python version       : 3.14.2
# IPython version      : 9.13.0
#
# conda environment: n/a
#
# Compiler    : Clang 21.1.4
# OS          : Darwin
# Release     : 25.5.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 14
# Architecture: 64bit
#
# mgplot     : 0.2.23
# numpy      : 2.4.6
# pandas     : 3.0.3
# readabs    : 0.1.9
# statsmodels: 0.14.6
# typing     : 3.10.0.0
#
# Watermark: 2.6.0

# %%
print("Finished")
# Out:
# Finished
